# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Airbnb_Open_Data.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16328\3936407181.py:1: DtypeWarning: Columns (0: license) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Airbnb_Open_Data.csv')

# %% [markdown]
# READING THE DATASET

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  str
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  str
#  4   host name                       102193 non-null  str
#  5   neighbourhood group             102570 non-null  str
#  6   neighbourhood                   102583 non-null  str
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  str
#  10  country code                    102468 non-null  str
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %% [markdown]
# CHECKING THE COLUMNS NAMES

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license','id']

# %% [markdown]
# PARTITIONING THE COLUMNS INTO TWO SEPEARTE GROUP

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %%
df = data[columns_to_keep]

# %% [markdown]
# DATA TO KEEP

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
data.drop(columns = columns_to_drop,inplace = True)

# %% [markdown]
# DROPPING IRRELEVANT COLUMNS

# %%
data.shape
# Out:
# (102599, 19)

# %%
data.rename(columns = {'NAME':'Name'}, inplace = True)

# %% [markdown]
# RENAMING A SINGLE COLUMNS

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
new_columns_names = []
for i in data.columns:
  new_columns_names.append(i.upper())

# %% [markdown]
# CHANGING ALL THE COLUMNS TO UPPERCASE

# %%
new_columns_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %% [markdown]
# CHECKING THE NEW COLUMNS

# %%
type(new_columns_names)
# Out:
# list

# %%
new_dataframe_to_modify = data.copy()

# %%
new_dataframe_to_modify = new_columns_names

# %%
new_dataframe_to_modify = data.copy()
new_dataframe_to_modify.columns = new_columns_names
new_dataframe_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='str')

# %%
data.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %% [markdown]
# CHECKING TOTAL DUPLICATES

# %%
data = data.drop_duplicates()

# %% [markdown]
# DROPPING ALL DUPLICATES

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %% [markdown]
# CHECKING TOTAL NA IN EACH COLUMNS

# %%
data.drop(columns =['last review'], inplace = True)

# %% [markdown]
# DROPPING A SINGLE COLUMN

# %%
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %%
data['host_identity_verified'].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 99342, dtype: str

# %% [markdown]
# CHANGING THE COLUMN TO UPPER CASE

# %%
data['host_identity_verified'] = data['host_identity_verified'].str.upper()

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data['instant_bookable'] = data['instant_bookable'].apply(lambda x: 1 if x ==True else 0)

# %% [markdown]
# CHANGING BOOLEAN TO 1 AND O

# %%
type(data['instant_bookable'][10])
# Out:
# numpy.int64

# %%
data.reset_index(inplace = True)

# %% [markdown]
# RESETTING THE INDEX COLUMN

# %%
data['price'] = data['price'].str.replace('$','')

# %%
data['price'] = data['price'].str.replace(',','')

# %%
data['price'] = data['price'].str.replace(' ','')

# %% [markdown]
# REMOVING AND REPLACING UNNECESSARY SYMBOLS AND SPACING WITH NOTHING

# %%
data['price']
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: str

# %%
type(data['price'][1])
# Out:
# str

# %%
data['price'].astype(int)[1]
# Out:
# np.int64(142)

# %% [markdown]
# CHANGING THE COLUMN DATA TYPE

# %%
data['price'] = data['price'].astype(int)

# %%
type(data['price'][1])
# Out:
# numpy.int64

# %% [markdown]
# CHECKING THE NEW DATA TYPE

# %%
data.drop(columns = 'index', inplace = True)

# %% [markdown]
# DROPPING FIRST INDEX COLUMN

# %%
new_columns_names = []
for i in data.columns:
  new_columns_names.append(i.capitalize())

# %% [markdown]
# CHANGING THE FIRST LETTER IN EACH COLUMN TO CAPITAL FORM

# %%
data.columns = new_columns_names

# %%
data
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data.to_csv('Cleaned_Airbnb_Data.csv', index = False )
